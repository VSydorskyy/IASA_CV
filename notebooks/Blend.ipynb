# %%
import pandas as pd

from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Data

# %%
df_nn = pd.read_csv('../data/nn_df.csv')
df_ml = pd.read_csv('../data/ml_df.csv')

# %%
df_nn
# Out:
#           age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0    0.954814    1   3  0.753336 -0.278393    1        0  0.019590      0
# 1   -1.914086    1   2 -0.098037  0.051329    0        1  1.638201      0
# 2   -1.472716    0   1 -0.098037 -0.840861    0        0  0.982007      0
# 3    0.182418    1   1 -0.665619 -0.220207    0        1  1.244485      0
# 4    0.292760    0   0 -0.665619  2.068456    0        1  0.588291      1
# ..        ...  ...  ..       ...       ...  ...      ...       ...    ...
# 292  0.954814    1   0  0.469545 -1.170584    0        0 -0.242887      1
# 293  0.954814    0   0 -0.438586 -0.976630    0        1 -0.592857      1
# 294  0.513445    1   0  1.831741 -1.383934    1        0 -2.605185      0
# 295  0.292760    0   0  0.469545 -0.123230    0        1 -1.161559      1
# 296 -1.031347    1   3 -1.233201  0.322866    0        1 -0.767842      0
#
#       oldpeak  slope        ca      thal  target  predicted_logits  fold_n  \
# ...

# %%
df_ml
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   63    1   0       140   187    0        0      144      1      4.0
# 293   63    0   0       124   197    0        1      136      1      0.0
# 294   59    1   0       164   176    1        0       90      0      1.0
# 295   57    0   0       140   241    0        1      123      1      0.2
# 296   45    1   3       110   264    0        1      132      0      1.2
#
#      slope  ca  thal  target  svc_pred   rf_pred  logreg_pred  gbc_pred
# ...

# %% [markdown]
# # Blend

# %%
target = df_nn['target']

# %%
roc_auc_score(
    target,
    (df_ml['rf_pred'] + df_nn['nn_pred'] + df_ml['logreg_pred']*0.75 + df_ml['gbc_pred']*0.05) 
)
# Out:
# 0.9188385916780978
